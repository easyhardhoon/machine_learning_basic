# %%
import numpy as np

# %%
x = np.array([1.0,2.0])
x
# Out:
# array([1., 2.])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y = np.array([2.0,3.0])

# %%
x+y
# Out:
# array([3., 5.])

# %%
x/y
# Out:
# array([0.5       , 0.66666667])

# %%
x * 5
# Out:
# array([ 5., 10.])

# %%
x.dtype
# Out:
# dtype('float64')

# %%
A = np.array([[1,2], [3,4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int64')

# %%
B = np.array([10,20])

# %%
A*B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
A+B
# Out:
# array([[11, 22],
#        [13, 24]])

# %%
A+B
# Out:
# array([[11, 22],
#        [13, 24]])

# %%
for a in A:
  print(a)
# Out:
# [1 2]
# [3 4]

# %%
A[0]
# Out:
# array([1, 2])

# %%
A[0][1]
# Out:
# 2

# %%
A = A.flatten()

# %%
A
# Out:
# array([1, 2, 3, 4])

# %%
A>15
# Out:
# array([False, False, False, False])

# %%
A[A>15]
# Out:
# array([], dtype=int64)

# %%
A[A>2]
# Out:
# array([3, 4])

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0,6,0.1)

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1, label = "sin")
plt.plot(x,y2, linestyle="--",label = "cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title("sin & cos ")
plt.legend()
plt.show()

# %%
from matplotlib.image import imread
img = imread("/content/20201121_233611.jpg")
plt.imshow(img)
plt.show()
